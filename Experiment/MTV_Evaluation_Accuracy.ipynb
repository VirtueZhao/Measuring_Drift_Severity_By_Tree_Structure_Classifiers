# %%
from MySkmultiflow.data import DataStream
from MySkmultiflow.trees import HoeffdingTreeClassifier
from statistics import mean, stdev
import MTVlib
import math
import csv
import pandas as pd

# %% [markdown]
# # Reverse Adult

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Adult_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '59'
    count = len(dataframe[target_index])
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_reverse(dataframe, target_index, i)
    
    target_idx = 59
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Reverse_Adult"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Reverse Bank

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Bank_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '41'
    count = len(dataframe[target_index])
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_reverse(dataframe, target_index, i)
    
    target_idx = 41
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Reverse_Bank"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Reverse Cardio

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Cardio_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '10'
    count = len(dataframe[target_index])
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_reverse(dataframe, target_index, i)
    
    target_idx = 10
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Reverse_Cardio"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Reverse Chess

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Chess_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '40'
    count = len(dataframe[target_index])
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_reverse(dataframe, target_index, i)
    
    target_idx = 40
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Reverse_Chess"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Reverse Credit

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Credit_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '26'
    count = len(dataframe[target_index])
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_reverse(dataframe, target_index, i)
    
    target_idx = 26
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Reverse_Credit"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Reverse Diamonds

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Diamonds_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '20'
    count = len(dataframe[target_index])
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_reverse(dataframe, target_index, i)
    
    target_idx = 20
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Reverse_Diamonds"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Reverse Gamma

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Gamma_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '10'
    count = len(dataframe[target_index])
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_reverse(dataframe, target_index, i)
    
    target_idx = 10
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Reverse_Gamma"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Reverse PokerPart

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_PokerPart_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '85'
    count = len(dataframe[target_index])
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_reverse(dataframe, target_index, i)
    
    target_idx = 85
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Reverse_PokerPart"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 0 Adult

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Adult_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '59'
    count = len(dataframe[target_index])
    drift_type = 0
    
    feature_shift_list = ['24', '47', '26', '46', '56', '57', '35', '48', '33', '8', '36', '18', '0', '50']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 59
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_0_Adult"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])
# Out:
# Currently Working on Iteration: 1
# generate dataframe for feature drift 0
# Currently Working on Iteration: 2
# generate dataframe for feature drift 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b96b99628b55> in <module>
#      18
#      19
# ---> 20     dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
#      21
#      22     target_idx = 59
#
# F:\Study\Master_Thesis_Di\Project\Model_To_Vector\MTVlib.py in generate_dataframe_feature(dataframe, target_index, feature_shift_list, random_seed, drift_type)
#     193             #                     print("new_" + str(new_key) + ".append(" + "old_" + str(old_key) +")")
#     194             else:
# --> 195                 for k in range(len(feature_shift_list)):
#     196                     new_key = feature_shift_list[k]
#     197                     new_values[new_key].append(old_values[new_key][i])
#
# KeyboardInterrupt:

# %% [markdown]
# # Feature 0 Bank

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Bank_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '41'
    count = len(dataframe[target_index])
    drift_type = 0
    
    feature_shift_list = ['37', '40', '24', '22', '1', '29', '33', '34', '27', '19']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 41
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_0_Bank"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 0 Cardio

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Cardio_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '10'
    count = len(dataframe[target_index])
    drift_type = 0
    
    feature_shift_list = ['4', '6', '7']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 10
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_0_Cardio"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 0 Chess

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Chess_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '40'
    count = len(dataframe[target_index])
    drift_type = 0
    
    feature_shift_list = ['32', '4', '7', '6', '3', '24', '33', '1', '36', '27']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 40
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_0_Chess"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 0 Credit

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Credit_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '26'
    count = len(dataframe[target_index])
    drift_type = 0
    
    feature_shift_list = ['0', '7', '4', '6', '19', '18']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 26
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_0_Credit"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 0 Diamonds

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Diamonds_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '20'
    count = len(dataframe[target_index])
    drift_type = 0
    
    feature_shift_list = ['12', '0', '5', '6', '17']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 20
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_0_Diamonds"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 0 Gamma

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Gamma_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '10'
    count = len(dataframe[target_index])
    drift_type = 0
    
    feature_shift_list = ['8', '0', '1']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 10
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_0_Gamma"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 0 PokerPart

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_PokerPart_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '85'
    count = len(dataframe[target_index])
    drift_type = 0
    
    feature_shift_list = ['13', '46', '54', '27', '26', '22', '65', '25', '9', '42', '20', '8', '5', '72', '43', '41', '6',
                         '1', '2', '29', '80']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 85
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_0_PokerPart"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 1 Adult

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Adult_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '59'
    count = len(dataframe[target_index])
    drift_type = 1
    
    feature_shift_list = ['24', '47', '26', '46', '56', '57', '35', '48', '33', '8', '36', '18', '0', '50']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 59
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_1_Adult"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 1 Bank

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Bank_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '41'
    count = len(dataframe[target_index])
    drift_type = 1
    
    feature_shift_list = ['37', '40', '24', '22', '1', '29', '33', '34', '27', '19']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 41
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_1_Bank"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 1 Cardio

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Cardio_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '10'
    count = len(dataframe[target_index])
    drift_type = 1
    
    feature_shift_list = ['4', '6', '7']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 10
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_1_Cardio"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 1 Chess

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Chess_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '40'
    count = len(dataframe[target_index])
    drift_type = 1
    
    feature_shift_list = ['32', '4', '7', '6', '3', '24', '33', '1', '36', '27']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 40
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_1_Chess"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 1 Credit

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Credit_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '26'
    count = len(dataframe[target_index])
    drift_type = 1
    
    feature_shift_list = ['0', '7', '4', '6', '19', '18']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 26
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_1_Credit"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 1 Diamonds

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Diamonds_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '20'
    count = len(dataframe[target_index])
    drift_type = 1
    
    feature_shift_list = ['12', '0', '5', '6', '17']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 20
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_1_Diamonds"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 1 Gamma

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_Gamma_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '10'
    count = len(dataframe[target_index])
    drift_type = 1
    
    feature_shift_list = ['8', '0', '1']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 10
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_1_Gamma"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])

# %% [markdown]
# # Feature 1 PokerPart

# %%
Iteration = 30
Accuracy_base_all = []
Accuracy_1_1_all = []
Accuracy_1_2_all = []
Accuracy_1_4_all = []
Accuracy_1_8_all = []

for i in range(Iteration):
    print("Currently Working on Iteration: " + str(i+1))
    
    dataframe = pd.read_csv('MTV_Datasets/Preprocessed_Datasets/Synthetic_PokerPart_Transformed.csv', header=None)
    dataframe.columns = dataframe.columns.astype(str)
    target_index = '85'
    count = len(dataframe[target_index])
    drift_type = 1
    
    feature_shift_list = ['13', '46', '54', '27', '26', '22', '65', '25', '9', '42', '20', '8', '5', '72', '43', '41', '6',
                         '1', '2', '29', '80']
    
    
    dataframe_base, dataframe_1_1, dataframe_1_2, dataframe_1_4, dataframe_1_8 = MTVlib.generate_dataframe_feature(dataframe, target_index, feature_shift_list, i, drift_type)
    
    target_idx = 85
    cat_features= list(range(target_idx))
    
    Stream_Base = DataStream(dataframe_base, target_idx=target_idx, cat_features=cat_features)
    Stream_1_1 = DataStream(dataframe_1_1, target_idx=target_idx, cat_features=cat_features)
    Stream_1_2 = DataStream(dataframe_1_2, target_idx=target_idx, cat_features=cat_features)
    Stream_1_4 = DataStream(dataframe_1_4, target_idx=target_idx, cat_features=cat_features)
    Stream_1_8 = DataStream(dataframe_1_8, target_idx=target_idx, cat_features=cat_features)

    HT_Base = HoeffdingTreeClassifier(binary_split=True, no_preprune=True)
    HT_Base.partial_fit(Stream_Base.X, Stream_Base.y)

    correct_base = 0
    correct_1_1 = 0
    correct_1_2 = 0
    correct_1_4 = 0
    correct_1_8 = 0

    count = len(dataframe[target_index])
    X_base, Y_base = Stream_Base.next_sample(count)
    X_1_1, Y_1_1 = Stream_1_1.next_sample(count)
    X_1_2, Y_1_2 = Stream_1_2.next_sample(count)
    X_1_4, Y_1_4 = Stream_1_4.next_sample(count)
    X_1_8, Y_1_8 = Stream_1_8.next_sample(count)

    pred_base = HT_Base.predict(X_base)
    pred_1_1 = HT_Base.predict(X_1_1)
    pred_1_2 = HT_Base.predict(X_1_2)
    pred_1_4 = HT_Base.predict(X_1_4)
    pred_1_8 = HT_Base.predict(X_1_8)


    for i in range(count):
        if pred_base[i] == Y_base[i]:
            correct_base += 1
        if pred_1_1[i] == Y_1_1[i]:
            correct_1_1 += 1
        if pred_1_2[i] == Y_1_2[i]:
            correct_1_2 += 1
        if pred_1_4[i] == Y_1_4[i]:
            correct_1_4 += 1
        if pred_1_8[i] == Y_1_8[i]:
            correct_1_8 += 1

    Accuracy_base = correct_base / count
    Accuracy_1_1 = correct_1_1 / count
    Accuracy_1_2 = correct_1_2 / count
    Accuracy_1_4 = correct_1_4 / count
    Accuracy_1_8 = correct_1_8 / count
    
    Accuracy_base_all.append(Accuracy_base)
    Accuracy_1_1_all.append(Accuracy_1_1)
    Accuracy_1_2_all.append(Accuracy_1_2)
    Accuracy_1_4_all.append(Accuracy_1_4)
    Accuracy_1_8_all.append(Accuracy_1_8)

with open('MTV_Evaluation\Evaluation_Accuracy.csv', 'a', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    
    mean_base = mean(Accuracy_base_all)
    mean_1 = mean(Accuracy_1_1_all)
    mean_2 = mean(Accuracy_1_2_all)
    mean_4 = mean(Accuracy_1_4_all)
    mean_8 = mean(Accuracy_1_8_all)
    
    stdev_base = stdev(Accuracy_base_all)
    stdev_1 = stdev(Accuracy_1_1_all)
    stdev_2 = stdev(Accuracy_1_2_all)
    stdev_4 = stdev(Accuracy_1_4_all)
    stdev_8 = stdev(Accuracy_1_8_all)
    
    r_b = str(round(mean_base,4)) + " $\pm$ " + str(round(stdev_base,4))
    r_1 = str(round(mean_1,4)) + " $\pm$ " + str(round(stdev_1,4))
    r_2 = str(round(mean_2,4)) + " $\pm$ " + str(round(stdev_2,4))
    r_4 = str(round(mean_4,4)) + " $\pm$ " + str(round(stdev_4,4))
    r_8 = str(round(mean_8,4)) + " $\pm$ " + str(round(stdev_8,4))
    
    dataset = "Feature_1_PokerPart"
    
    writer.writerow([dataset, r_b, r_1, r_2, r_4, r_8])
